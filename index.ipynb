# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#Your code here
df.columns = df.columns.str.lower()
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
#Your code here
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Change the index back

# %%
# Your code here
df = df.reset_index()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
# Your code here
unique_station_line = df.groupby('station')['linename'].nunique()

unique_station_line = unique_station_line.to_frame()

unique_station_line.rename(columns={"linename": "lines_through_count"}, inplace =True)
unique_station_line.head()

unique_station_line.sort_values(by=['lines_through_count'], ascending=False)

df = df.set_index('station')
#df2 = df.set_index('station', inplace=True).join(unique_station_line.set_index('station'))

df2 = df.join(unique_station_line)

df2.sort_values(by=['lines_through_count'],ascending=False)

df2.head(30)
# Out:
#         linename   c/a  unit       scp division        date      time  \
# station
# 1 AV           L  H007  R248  00-00-00      BMT  08/25/2018  00:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/25/2018  04:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/25/2018  08:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/25/2018  12:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/25/2018  16:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/25/2018  20:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/26/2018  00:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/26/2018  04:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/26/2018  08:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/26/2018  12:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/26/2018  16:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/26/2018  20:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/27/2018  00:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/27/2018  04:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/27/2018  08:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/27/2018  12:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/27/2018  16:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/27/2018  20:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/28/2018  00:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/28/2018  04:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/28/2018  08:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/28/2018  12:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/28/2018  16:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/28/2018  20:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/29/2018  00:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/29/2018  04:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/29/2018  08:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/29/2018  12:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/29/2018  16:00:00
# 1 AV           L  H007  R248  00-00-00      BMT  08/29/2018  20:00:00
#
#             desc   entries  \
# station
# 1 AV     REGULAR  13868622
# 1 AV     REGULAR  13868725
# 1 AV     REGULAR  13868800
# 1 AV     REGULAR  13869196
# 1 AV     REGULAR  13869796
# 1 AV     REGULAR  13870339
# 1 AV     REGULAR  13870717
# 1 AV     REGULAR  13870783
# 1 AV     REGULAR  13870835
# 1 AV     REGULAR  13871228
# 1 AV     REGULAR  13871773
# 1 AV     REGULAR  13872303
# 1 AV     REGULAR  13872585
# 1 AV     REGULAR  13872618
# 1 AV     REGULAR  13872870
# 1 AV     REGULAR  13873926
# 1 AV     REGULAR  13874622
# 1 AV     REGULAR  13875441
# 1 AV     REGULAR  13875785
# 1 AV     REGULAR  13875833
# 1 AV     REGULAR  13876131
# 1 AV     REGULAR  13877236
# 1 AV     REGULAR  13877912
# 1 AV     REGULAR  13878845
# 1 AV     REGULAR  13879228
# 1 AV     REGULAR  13879264
# 1 AV     REGULAR  13879539
# 1 AV     REGULAR  13880711
# 1 AV     REGULAR  13881403
# 1 AV     REGULAR  13882347
#
#          exits                                                                 \
# station
# 1 AV                                              15561330
# 1 AV                                              15561554
# 1 AV                                              15561822
# 1 AV                                              15562502
# 1 AV                                              15563471
# 1 AV                                              15564499
# 1 AV                                              15565139
# 1 AV                                              15565395
# 1 AV                                              15565591
# 1 AV                                              15566186
# 1 AV                                              15567045
# 1 AV                                              15567902
# 1 AV                                              15568375
# 1 AV                                              15568457
# 1 AV                                              15569162
# 1 AV                                              15570239
# 1 AV                                              15570908
# 1 AV                                              15571723
# 1 AV                                              15572116
# 1 AV                                              15572163
# 1 AV                                              15572801
# 1 AV                                              15573943
# 1 AV                                              15574695
# 1 AV                                              15575517
# 1 AV                                              15575965
# 1 AV                                              15576013
# 1 AV                                              15576700
# 1 AV                                              15577955
# 1 AV                                              15578707
# 1 AV                                              15579581
#
#          lines_through_count
# station
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1
# 1 AV                       1

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.strip().lower()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'division', 'date', 'time', 'desc',
#        'entries', 'exits'],
#       dtype='object')

# %% [markdown]
# ## Group the Data by Day of Week and Plot the Sum of The Numeric Columns

# %%
#Your code here
df.groupby('date').sum()
# Out:
#                   entries         exits
# date
# 08/25/2018  1115661545514  909142081474
# 08/26/2018  1192306179082  959223750461
# 08/27/2018  1114237052454  911938153513
# 08/28/2018  1143313287046  942230721477
# 08/29/2018  1123655222441  920630864687
# 08/30/2018  1122723988662  920691927110
# 08/31/2018  1110224700078  906799065337

# %% [markdown]
# ## Group the Data by Weekend/Weekday and Plot the Sum of the Numeric Columns

# %%
#Your code here
import datetime as dt

day_of_week = df.groupby('date').sum()
day_of_week.reset_index(inplace = True)
day_of_week['date'] = pd.to_datetime(day_of_week.date)
day_of_week.date.dt.isoweekday().head()


day_of_week.head(10)
#day_of_week.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-a767853bd5ea> in <module>()
#       5 day_of_week.reset_index(inplace = True)
#       6 day_of_week['date'] = pd.to_datetime(day_of_week.date)
# ----> 7 day_of_week.date.dt.isoweekday().head()
#       8 #for i in day_of_week.date:
#       9 #    print(i)
#
# AttributeError: 'DatetimeProperties' object has no attribute 'isoweekday'

# %%
def weekday(text):
    val = text.dayofweek
    if val == 0:
        day = 'Monday'
    elif val == 1:
        day = 'Tuesday'
    elif val == 2:
        day = 'Wednesday'
    elif val == 3:
        day = 'Thursday'
    elif val == 4:
        day = 'Friday'
    elif val == 5:
        day = 'Saturday'
    else:
        day = "Sunday"
        
    return day

# %%
df['WeekDay'] = df.date.map(weekday)
df.head(15)

# %%
df['WeekDay'].value_counts()

# %% [markdown]
# ## Analysis Question:
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here

#df.drop(scp, desc)

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
